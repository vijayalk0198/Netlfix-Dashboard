# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data.head()
# Out:
#   show_id   type       title         director  \
# 0   s6079  Movie   Abhinetri      A. L. Vijay
# 1   s3538  Movie    Watchman      A. L. Vijay
# 2   s2390  Movie  Asura Guru     A. Raajdheep
# 3   s5550  Movie   Salaakhen        A. Salaam
# 4   s4050  Movie      Sarkar  A.R. Murugadoss
#
#                                                 cast country  \
# 0  Tamannaah Bhatia, Prabhu Deva, Sonu Sood, Sapt...   India
# 1  G.V. Prakash Kumar, Samyuktha Hegde, Suman, Ra...   India
# 2  Vikram Prabhu, Subbaraju, Mahima Nambiar, Yogi...   India
# 3  Shashi Kapoor, Sulakshana Pandit, Mehmood, Sud...   India
# 4  Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...     NaN
#
#           date_added  release_year rating duration  \
# 0        May 1, 2018          2016  TV-14  131 min
# 1  September 4, 2019          2019  TV-14   93 min
# 2      June 13, 2020          2020  TV-14  117 min
# 3      April 1, 2017          1975  TV-14  134 min
# 4      March 2, 2019          2018  TV-MA  162 min
#
#                                            listed_in  \
# 0   Comedies, International Movies, Sci-Fi & Fantasy
# 1             Comedies, Dramas, International Movies
# 2                       Dramas, International Movies
# 3  Action & Adventure, International Movies, Musi...
# 4   Action & Adventure, Dramas, International Movies
#
#                                          description
# 0  Due to family pressure, a corporate man reluct...
# 1  Rushing to pay off a loan shark, a young man b...
# 2  For a tech-savvy thief, elaborate robberies an...
# 3  Two close childhood friends take drastically d...
# 4  A ruthless businessman’s mission to expose ele...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data['date_added'] = pd.to_datetime(data['date_added'], errors = 'coerce')
columns_to_fill = ['cast', 'director']
data[columns_to_fill] = data[columns_to_fill].fillna('No Data')

# %%
# Drop the 'description' column
data.drop(columns=['description'], inplace=True)

# %%
def replace_nat_with_release_year_end(data):
    data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce') # Ensure datetime, coerce errors.
    data['release_year'] = pd.to_numeric(data['release_year'], errors='coerce') # Ensure numeric release year.

    nat_dates = data['date_added'].isnull() # Find NaT dates.

    data.loc[nat_dates, 'date_added'] = pd.to_datetime(data.loc[nat_dates, 'release_year'].astype(str) + '-12-31', errors='coerce')

    return data

# %%
data = replace_nat_with_release_year_end(data)

# %%
data['rating'].unique()
# Out:
# array(['TV-14', 'TV-MA', 'PG-13', 'PG', 'TV-PG', 'NR', 'R', 'NC-17',
#        'TV-Y', 'TV-Y7', 'TV-G', nan, 'G', 'TV-Y7-FV', 'UR', '74 min',
#        '84 min', '66 min'], dtype=object)

# %%
# Filter rows where rating is '74 min' or '84 min'
incorrect_ratings = data[data['rating'].isin(['74 min', '84 min','66 min'])]

# Display the filtered rows
print(incorrect_ratings)
# Out:
#      show_id   type                                 title    director  \
# 3237   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 3238   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 3239   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 3237  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 3238  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 3239  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in
# 3237    Movies
# 3238    Movies
# 3239    Movies

# %%
# Identify rows where rating contains '74 min' or '84 min'
incorrect_ratings = ['74 min', '84 min', '66 min']

# Move incorrect values to 'duration' column
data.loc[data['rating'].isin(incorrect_ratings), 'duration'] = data['rating']

# Replace '74 min' and '84 min' with 'NR' in the 'rating' column
data.loc[data['rating'].isin(incorrect_ratings), 'rating'] = 'NR'

# Display the updated dataset
print(data[['rating', 'duration']].head())
# Out:
#   rating duration
# 0  TV-14  131 min
# 1  TV-14   93 min
# 2  TV-14  117 min
# 3  TV-14  134 min
# 4  TV-MA  162 min

# %%
# Define mapping for rating standardization
rating_mapping = {
    'TV-G': 'G',  
    'UR': 'NR',  
    'TV-PG': 'PG',  
    'TV-MA': 'R',  
    'NC-17': 'R',  
    'PG-13': 'TV-13',  
    'TV-Y7-FV': 'TV-Y7'
}

# Apply the mapping
data['rating'] = data['rating'].replace(rating_mapping)

# Display unique ratings after cleaning
print(data['rating'].unique())
# Out:
# ['TV-14' 'R' 'TV-13' 'PG' 'NR' 'TV-Y' 'TV-Y7' 'G' nan]

# %%
# Replace NaN values in 'rating' with 'NR'
data['rating'] = data['rating'].fillna('NR')

# Display unique values after filling NaNs
print(data['rating'].unique())
# Out:
# ['TV-14' 'R' 'TV-13' 'PG' 'NR' 'TV-Y' 'TV-Y7' 'G']

# %%
data['type'].nunique()
# Out:
# 2

# %%
data['country'].nunique()
# Out:
# 748

# %%
print(data['country'].nunique)
# Out:
# <bound method IndexOpsMixin.nunique of 0           India
# 1           India
# 2           India
# 3           India
# 4             NaN
#           ...
# 8802        India
# 8803        Japan
# 8804          NaN
# 8805       Mexico
# 8806    Australia
# Name: country, Length: 8807, dtype: object>

# %%
# Replace NaN values in 'country' with 'Not Listed'
data['country'] = data['country'].fillna('Not Listed')

# %%
data['country_count'] = data['country'].apply(lambda x: 0 if x == "Not Listed" else len(str(x).split(',')))

# %%
data.sample(5)
# Out:
#      show_id     type                               title       director  \
# 7361   s5142  TV Show  Kantaro: The Sweet Tooth Salaryman        No Data
# 3760   s8336    Movie                    The Green Hornet  Michel Gondry
# 6642   s6374  TV Show               Braxton Family Values        No Data
# 85     s6272    Movie                     Bedtime Stories  Adam Shankman
# 1036   s7906    Movie                 Running Out Of Time   Chris Stokes
#
#                                                    cast        country  \
# 7361  Matsuya Onoe, Ren Ishikawa, Hiroyuki Onoue, Ha...          Japan
# 3760  Seth Rogen, Jay Chou, Cameron Diaz, Tom Wilkin...  United States
# 6642  Toni Braxton, Trina Braxton, Traci Braxton, To...  United States
# 85    Adam Sandler, Keri Russell, Guy Pearce, Russel...  United States
# 1036  Tasha Smith, RonReaco Lee, Telma Hopkins, Sydn...  United States
#
#      date_added  release_year rating   duration  \
# 7361 2017-12-01          2017     PG   1 Season
# 3760 2020-04-18          2011  TV-13    119 min
# 6642 2020-02-15          2014     PG  2 Seasons
# 85   2019-03-05          2008     PG    100 min
# 1036 2019-08-01          2018  TV-14     88 min
#
#                                 listed_in  country_count
# 7361  International TV Shows, TV Comedies              1
# 3760         Action & Adventure, Comedies              1
# 6642                           Reality TV              1
# 85     Children & Family Movies, Comedies              1
# 1036                            Thrillers              1

# %%
# Split genres into individual values and flatten the list
genres = data['listed_in'].dropna().str.split(',').explode().str.strip()

# Count the frequency of each genre
genre_counts = genres.value_counts()

# Display the most frequent genres
print(genre_counts)
# Out:
# International Movies            2752
# Dramas                          2427
# Comedies                        1674
# International TV Shows          1351
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        763
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# TV Comedies                      581
# Thrillers                        577
# Crime TV Shows                   470
# Kids' TV                         451
# Docuseries                       395
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 253
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     176
# Spanish-Language TV Shows        174
# TV Action & Adventure            168
# Korean TV Shows                  151
# Classic Movies                   116
# LGBTQ Movies                     102
# TV Mysteries                      98
# Science & Nature TV               92
# TV Sci-Fi & Fantasy               84
# TV Horror                         75
# Cult Movies                       71
# Anime Features                    71
# Teen TV Shows                     69
# Faith & Spirituality              65
# TV Thrillers                      57
# Movies                            57
# Stand-Up Comedy & Talk Shows      56
# Classic & Cult TV                 28
# TV Shows                          16
# Name: listed_in, dtype: int64

# %%
# Extract minutes for movies
data['movie_duration'] = data['duration'].str.extract(r'(\d+)\s*min')[0].astype(float)

# Extract number of seasons for TV shows
data['num_seasons'] = data['duration'].str.extract(r'(\d+)\s*Season')[0].astype(float)

# Fill NaN values with 0 for easier analysis
data['movie_duration'].fillna(0, inplace=True)
data['num_seasons'].fillna(0, inplace=True)

# Drop the original 'duration' column as it's no longer needed
data.drop(columns=['duration'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   show_id         8807 non-null   object
#  1   type            8807 non-null   object
#  2   title           8807 non-null   object
#  3   director        8807 non-null   object
#  4   cast            8807 non-null   object
#  5   country         8807 non-null   object
#  6   date_added      8807 non-null   datetime64[ns]
#  7   release_year    8807 non-null   int64
#  8   rating          8807 non-null   object
#  9   listed_in       8807 non-null   object
#  10  country_count   8807 non-null   int64
#  11  movie_duration  8807 non-null   float64
#  12  num_seasons     8807 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 894.6+ KB

# %%
data.sample(10)
# Out:
#      show_id     type                                         title  \
# 5195   s5124    Movie                                  Pottersville
# 2654   s4116    Movie                Ken Jeong: You Complete Me, Ho
# 7141   s5414  TV Show                                         Gypsy
# 1669   s4813    Movie                                           TAU
# 1662   s3134    Movie                                           Don
# 7642   s7469  TV Show                                     Miss Rose
# 5837   s1190    Movie  Nate Bargatze: The Greatest Average American
# 3353   s2024    Movie                                        Kaagar
# 4404    s955    Movie                           The Yeti Adventures
# 6866   s4264  TV Show                                  Demon's Path
#
#                                  director  \
# 5195                       Seth Henrikson
# 2654                           Jon M. Chu
# 7141                              No Data
# 1669                Federico D'Alessandro
# 1662                        Farhan Akhtar
# 7642                              No Data
# 5837                          Troy Miller
# 3353                        Makarand Mane
# 4404  Pierre Greco, Nancy Florence Savard
# 6866                              No Data
#
#                                                    cast  \
# 5195  Michael Shannon, Judy Greer, Thomas Lennon, Ro...
# 2654                                          Ken Jeong
# 7141  Naomi Watts, Billy Crudup, Sophie Cookson, Kar...
# 1669               Maika Monroe, Ed Skrein, Gary Oldman
# 1662  Shah Rukh Khan, Priyanka Chopra, Arjun Rampal,...
# 7642  Roy Chiu, Megan Lai, Paul Hsu, Tia Lee, Chunya...
# 5837                                      Nate Bargatze
# 3353  Rinku Rajguru, Shubhankar Tawde, Shashank Shen...
# 4404  Rachelle Lefevre, Noel Fisher, Colm Feore, Jul...
# 6866  Wai Ai, Jim Chim Sui Man, Kwok-Pong Chan, Feli...
#
#                             country date_added  release_year rating  \
# 5195                  United States 2017-12-15          2017  TV-13
# 2654                  United States 2019-02-14          2019      R
# 7141  United States, United Kingdom 2017-06-30          2017      R
# 1669                  United States 2018-06-29          2018      R
# 1662                          India 2019-12-15          2006  TV-14
# 7642                         Taiwan 2016-08-01          2015      R
# 5837                  United States 2021-03-18          2021      G
# 3353                          India 2020-09-10          2019      R
# 4404                         Canada 2021-05-01          2018     PG
# 6866                     Not Listed 2018-12-22          2018  TV-14
#
#                                               listed_in  country_count  \
# 5195                       Comedies, Independent Movies              1
# 2654                                    Stand-Up Comedy              1
# 7141                                          TV Dramas              2
# 1669                        Sci-Fi & Fantasy, Thrillers              1
# 1662           Action & Adventure, International Movies              1
# 7642  International TV Shows, Romantic TV Shows, TV ...              1
# 5837                                    Stand-Up Comedy              1
# 3353      Dramas, International Movies, Romantic Movies              1
# 4404                 Children & Family Movies, Comedies              1
# 6866  Crime TV Shows, International TV Shows, TV Dramas              0
#
#       movie_duration  num_seasons
# 5195            86.0          0.0
# 2654            62.0          0.0
# 7141             0.0          1.0
# 1669            98.0          0.0
# 1662           169.0          0.0
# 7642             0.0          1.0
# 5837            60.0          0.0
# 3353           130.0          0.0
# 4404            85.0          0.0
# 6866             0.0          1.0

# %%
data['year_added'] = data['date_added'].dt.year.astype(int)
data['month_added'] = data['date_added'].dt.month_name()
data['day_added'] = data['date_added'].dt.day_name()

# Filter data for years between 2000 and 2020
data_2000_2020 = data[(data['year_added'] >= 2000) & (data['year_added'] <= 2020)]

# Filter data for years between 2010 and 2020
data_2010_2020 = data[(data['year_added'] >= 2010) & (data['year_added'] <= 2020)]

# %%
len(data_2000_2020)
# Out:
# 7309

# %%
len(data_2010_2020)
# Out:
# 7302

# %%
data_2010_2020.sample(5)
# Out:
#      show_id     type               title         director  \
# 1836   s4215    Movie           Lionheart  Genevieve Nnaji
# 6839   s4760  TV Show        Dark Tourist          No Data
# 1501   s7115    Movie             Jackpot    Dustin Nguyen
# 6488   s3781  TV Show  Arthdal Chronicles          No Data
# 1838   s8182    Movie  The Adventure Club   Geoff Anderson
#
#                                                    cast      country  \
# 1836  Genevieve Nnaji, Nkem Owoh, Pete Edochie, Onye...      Nigeria
# 6839                                            No Data  New Zealand
# 1501        Chi Tai, Lan Ngoc, Dustin Nguyen, Thu Trang      Vietnam
# 6488  Song Joong-ki, Jang Dong-gun, Kim Ji-won, Kim ...  South Korea
# 1838  Sam Ashe Arnold, Jakob Davies, Dalila Bela, Ro...       Canada
#
#      date_added  release_year rating  \
# 1836 2019-01-04          2018     PG
# 6839 2018-07-20          2018      R
# 1501 2018-10-06          2015  TV-14
# 6488 2019-06-02          2019      R
# 1838 2017-05-10          2016  TV-Y7
#
#                                               listed_in  country_count  \
# 1836               Comedies, Dramas, Independent Movies              1
# 6839                 Docuseries, International TV Shows              1
# 1501             Comedies, Dramas, International Movies              1
# 6488  International TV Shows, Korean TV Shows, TV Ac...              1
# 1838                           Children & Family Movies              1
#
#       movie_duration  num_seasons  year_added month_added  day_added
# 1836            95.0          0.0        2019     January     Friday
# 6839             0.0          1.0        2018        July     Friday
# 1501            92.0          0.0        2018     October   Saturday
# 6488             0.0          1.0        2019        June     Sunday
# 1838            88.0          0.0        2017         May  Wednesday

# %%
# Save the cleaned dataset (2010-2020) to a CSV file
data_2010_2020.to_csv('netflix_2010_2020_cleaned.csv', index=False)

print("Cleaned dataset saved as 'netflix_2010_2020_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'netflix_2010_2020_cleaned.csv'
